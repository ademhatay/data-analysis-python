# %% [markdown]
# <a href="https://colab.research.google.com/github/ademhatay/pythonForMachineLearnig/blob/main/DataFrameGiris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy ve Pandas Basit Kullanım (TEMEL)

# %% [markdown]
# 1.   kütüphaneleri import ediyoruz.
# 2.   numpy.array ile verilerimizi oluşturuyoruz.
# 3.   sutun isimlerini belirtiyoruz (dataframe oluştururken kullanacağız.)
# 4.   dataframe (veri seti) oluşuruyoruz
#
# ```
# pd.DataFrame(data,columns)
# ```
# data olarak `veri`'yi gödneriyoruz. Columns olarak `sutun_isimleri`'ni gönderiyoruz.
# 5.   Print ile `veriseti`'ni (dataframe) ekrana bastırıyoruz.

# %%
import numpy as np
import pandas as pd

veri = np.array([[2, 3], [10, 7], [20, 9], [30, 14], [40, 15]])

sutun_isimleri = ['uzunluk', 'agirlik']

veriseti = pd.DataFrame(data=veri, columns=sutun_isimleri)
print(veriseti)
# Out:
#    uzunluk  agirlik
# 0        2        3
# 1       10        7
# 2       20        9
# 3       30       14
# 4       40       15
